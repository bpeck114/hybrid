# %% [markdown]
# # Hybrid: 30km 60" Rayleigh 15" Sodium Study

# %%
import os, fnmatch
import importlib
import pylab as plt
import numpy as np
from astropy.io import fits


# Specific packages (may need extra steps to import)
import readbin
from paarti.utils import maos_utils
from paarti import psfs, psf_plots
from paarti import psfs, psf_plots
from paarti.psf_metrics import metrics
from bpeck.hybrid import on_axis_study
from bpeck.mcao import act_study

# %% [markdown]
# ## Parameters

# %%
seed = 1
bandpass = 3
start_index = 9000

# %%
os.getcwd()
# Out:
# '/scr2/bpeck/work/hybrid/30km60asR_15as1S_lgs_study1A'

# %%
os.getcwd()
# Out:
# '/scr2/bpeck/work/hybrid/30km60asR_15as1S_lgs_study1A'

# %%
os.chdir("..")

# %% [markdown]
# ## 0 Sodium

# %%
os.chdir("30km60asR_15as0S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_0_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_0, clos_mean_nm_0_0, open_xx_mean_nm_0_0, clos_xx_mean_nm_0_0 = wfe_0_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_0_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_2, clos_mean_nm_0_2, open_xx_mean_nm_0_2, clos_xx_mean_nm_0_2 = wfe_0_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_0_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_4, clos_mean_nm_0_4, open_xx_mean_nm_0_4, clos_xx_mean_nm_0_4 = wfe_0_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_0_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_6, clos_mean_nm_0_6, open_xx_mean_nm_0_6, clos_xx_mean_nm_0_6 = wfe_0_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_0_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_8, clos_mean_nm_0_8, open_xx_mean_nm_0_8, clos_xx_mean_nm_0_8 = wfe_0_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_0_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_10, clos_mean_nm_0_10, open_xx_mean_nm_0_10, clos_xx_mean_nm_0_10 = wfe_0_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_0_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_14, clos_mean_nm_0_14, open_xx_mean_nm_0_14, clos_xx_mean_nm_0_14 = wfe_0_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_0_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_18, clos_mean_nm_0_18, open_xx_mean_nm_0_18, clos_xx_mean_nm_0_18 = wfe_0_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_0_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_22, clos_mean_nm_0_22, open_xx_mean_nm_0_22, clos_xx_mean_nm_0_22 = wfe_0_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_0_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_26, clos_mean_nm_0_26, open_xx_mean_nm_0_26, clos_xx_mean_nm_0_26 = wfe_0_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_0_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_0_30, clos_mean_nm_0_30, open_xx_mean_nm_0_30, clos_xx_mean_nm_0_30 = wfe_0_30
os.chdir("..")

os.chdir("..")

# %%
print(clos_xx_mean_nm_0_2[0][0])
# Out:
# 505.95063913856535

# %% [markdown]
# ## 1 Sodium

# %%
os.chdir("30km60asR_15as1S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_1_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_0, clos_mean_nm_1_0, open_xx_mean_nm_1_0, clos_xx_mean_nm_1_0 = wfe_1_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_1_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_2, clos_mean_nm_1_2, open_xx_mean_nm_1_2, clos_xx_mean_nm_1_2 = wfe_1_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_1_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_4, clos_mean_nm_1_4, open_xx_mean_nm_1_4, clos_xx_mean_nm_1_4 = wfe_1_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_1_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_6, clos_mean_nm_1_6, open_xx_mean_nm_1_6, clos_xx_mean_nm_1_6 = wfe_1_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_1_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_8, clos_mean_nm_1_8, open_xx_mean_nm_1_8, clos_xx_mean_nm_1_8 = wfe_1_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_1_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_10, clos_mean_nm_1_10, open_xx_mean_nm_1_10, clos_xx_mean_nm_1_10 = wfe_1_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_1_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_14, clos_mean_nm_1_14, open_xx_mean_nm_1_14, clos_xx_mean_nm_1_14 = wfe_1_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_1_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_18, clos_mean_nm_1_18, open_xx_mean_nm_1_18, clos_xx_mean_nm_1_18 = wfe_1_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_1_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_22, clos_mean_nm_1_22, open_xx_mean_nm_1_22, clos_xx_mean_nm_1_22 = wfe_1_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_1_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_26, clos_mean_nm_1_26, open_xx_mean_nm_1_26, clos_xx_mean_nm_1_26 = wfe_1_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_1_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_1_30, clos_mean_nm_1_30, open_xx_mean_nm_1_30, clos_xx_mean_nm_1_30 = wfe_1_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 2 Sodium

# %%
os.chdir("30km60asR_15as2S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_2_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_0, clos_mean_nm_2_0, open_xx_mean_nm_2_0, clos_xx_mean_nm_2_0 = wfe_2_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_2_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_2, clos_mean_nm_2_2, open_xx_mean_nm_2_2, clos_xx_mean_nm_2_2 = wfe_2_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_2_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_4, clos_mean_nm_2_4, open_xx_mean_nm_2_4, clos_xx_mean_nm_2_4 = wfe_2_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_2_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_6, clos_mean_nm_2_6, open_xx_mean_nm_2_6, clos_xx_mean_nm_2_6 = wfe_2_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_2_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_8, clos_mean_nm_2_8, open_xx_mean_nm_2_8, clos_xx_mean_nm_2_8 = wfe_2_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_2_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_10, clos_mean_nm_2_10, open_xx_mean_nm_2_10, clos_xx_mean_nm_2_10 = wfe_2_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_2_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_14, clos_mean_nm_2_14, open_xx_mean_nm_2_14, clos_xx_mean_nm_2_14 = wfe_2_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_2_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_18, clos_mean_nm_2_18, open_xx_mean_nm_2_18, clos_xx_mean_nm_2_18 = wfe_2_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_2_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_22, clos_mean_nm_2_22, open_xx_mean_nm_2_22, clos_xx_mean_nm_2_22 = wfe_2_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_2_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_26, clos_mean_nm_2_26, open_xx_mean_nm_2_26, clos_xx_mean_nm_2_26 = wfe_2_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_2_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_2_30, clos_mean_nm_2_30, open_xx_mean_nm_2_30, clos_xx_mean_nm_2_30 = wfe_2_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 3 Sodium

# %%
os.chdir("30km60asR_15as3S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_3_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_0, clos_mean_nm_3_0, open_xx_mean_nm_3_0, clos_xx_mean_nm_3_0 = wfe_3_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_3_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_2, clos_mean_nm_3_2, open_xx_mean_nm_3_2, clos_xx_mean_nm_3_2 = wfe_3_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_3_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_4, clos_mean_nm_3_4, open_xx_mean_nm_3_4, clos_xx_mean_nm_3_4 = wfe_3_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_3_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_6, clos_mean_nm_3_6, open_xx_mean_nm_3_6, clos_xx_mean_nm_3_6 = wfe_3_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_3_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_8, clos_mean_nm_3_8, open_xx_mean_nm_3_8, clos_xx_mean_nm_3_8 = wfe_3_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_3_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_10, clos_mean_nm_3_10, open_xx_mean_nm_3_10, clos_xx_mean_nm_3_10 = wfe_3_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_3_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_14, clos_mean_nm_3_14, open_xx_mean_nm_3_14, clos_xx_mean_nm_3_14 = wfe_3_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_3_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_18, clos_mean_nm_3_18, open_xx_mean_nm_3_18, clos_xx_mean_nm_3_18 = wfe_3_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_3_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_22, clos_mean_nm_3_22, open_xx_mean_nm_3_22, clos_xx_mean_nm_3_22 = wfe_3_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_3_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_26, clos_mean_nm_3_26, open_xx_mean_nm_3_26, clos_xx_mean_nm_3_26 = wfe_3_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_3_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_3_30, clos_mean_nm_3_30, open_xx_mean_nm_3_30, clos_xx_mean_nm_3_30 = wfe_3_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 4 Sodium

# %%
os.chdir("30km60asR_15as4S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_4_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_0, clos_mean_nm_4_0, open_xx_mean_nm_4_0, clos_xx_mean_nm_4_0 = wfe_4_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_4_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_2, clos_mean_nm_4_2, open_xx_mean_nm_4_2, clos_xx_mean_nm_4_2 = wfe_4_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_4_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_4, clos_mean_nm_4_4, open_xx_mean_nm_4_4, clos_xx_mean_nm_4_4 = wfe_4_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_4_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_6, clos_mean_nm_4_6, open_xx_mean_nm_4_6, clos_xx_mean_nm_4_6 = wfe_4_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_4_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_8, clos_mean_nm_4_8, open_xx_mean_nm_4_8, clos_xx_mean_nm_4_8 = wfe_4_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_4_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_10, clos_mean_nm_4_10, open_xx_mean_nm_4_10, clos_xx_mean_nm_4_10 = wfe_4_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_4_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_14, clos_mean_nm_4_14, open_xx_mean_nm_4_14, clos_xx_mean_nm_4_14 = wfe_4_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_4_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_18, clos_mean_nm_4_18, open_xx_mean_nm_4_18, clos_xx_mean_nm_4_18 = wfe_4_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_4_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_22, clos_mean_nm_4_22, open_xx_mean_nm_4_22, clos_xx_mean_nm_4_22 = wfe_4_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_4_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_26, clos_mean_nm_4_26, open_xx_mean_nm_4_26, clos_xx_mean_nm_4_26 = wfe_4_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_4_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_4_30, clos_mean_nm_4_30, open_xx_mean_nm_4_30, clos_xx_mean_nm_4_30 = wfe_4_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 5 Sodium

# %%
os.chdir("30km60asR_15as5S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_5_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_0, clos_mean_nm_5_0, open_xx_mean_nm_5_0, clos_xx_mean_nm_5_0 = wfe_5_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_5_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_2, clos_mean_nm_5_2, open_xx_mean_nm_5_2, clos_xx_mean_nm_5_2 = wfe_5_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_5_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_4, clos_mean_nm_5_4, open_xx_mean_nm_5_4, clos_xx_mean_nm_5_4 = wfe_5_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_5_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_6, clos_mean_nm_5_6, open_xx_mean_nm_5_6, clos_xx_mean_nm_5_6 = wfe_5_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_5_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_8, clos_mean_nm_5_8, open_xx_mean_nm_5_8, clos_xx_mean_nm_5_8 = wfe_5_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_5_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_10, clos_mean_nm_5_10, open_xx_mean_nm_5_10, clos_xx_mean_nm_5_10 = wfe_5_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_5_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_14, clos_mean_nm_5_14, open_xx_mean_nm_5_14, clos_xx_mean_nm_5_14 = wfe_5_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_5_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_18, clos_mean_nm_5_18, open_xx_mean_nm_5_18, clos_xx_mean_nm_5_18 = wfe_5_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_5_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_22, clos_mean_nm_5_22, open_xx_mean_nm_5_22, clos_xx_mean_nm_5_22 = wfe_5_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_5_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_26, clos_mean_nm_5_26, open_xx_mean_nm_5_26, clos_xx_mean_nm_5_26 = wfe_5_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_5_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_5_30, clos_mean_nm_5_30, open_xx_mean_nm_5_30, clos_xx_mean_nm_5_30 = wfe_5_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 6 Sodium

# %%
os.chdir("30km60asR_15as6S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_6_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_0, clos_mean_nm_6_0, open_xx_mean_nm_6_0, clos_xx_mean_nm_6_0 = wfe_6_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_6_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_2, clos_mean_nm_6_2, open_xx_mean_nm_6_2, clos_xx_mean_nm_6_2 = wfe_6_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_6_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_4, clos_mean_nm_6_4, open_xx_mean_nm_6_4, clos_xx_mean_nm_6_4 = wfe_6_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_6_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_6, clos_mean_nm_6_6, open_xx_mean_nm_6_6, clos_xx_mean_nm_6_6 = wfe_6_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_6_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_8, clos_mean_nm_6_8, open_xx_mean_nm_6_8, clos_xx_mean_nm_6_8 = wfe_6_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_6_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_10, clos_mean_nm_6_10, open_xx_mean_nm_6_10, clos_xx_mean_nm_6_10 = wfe_6_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_6_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_14, clos_mean_nm_6_14, open_xx_mean_nm_6_14, clos_xx_mean_nm_6_14 = wfe_6_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_6_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_18, clos_mean_nm_6_18, open_xx_mean_nm_6_18, clos_xx_mean_nm_6_18 = wfe_6_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_6_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_22, clos_mean_nm_6_22, open_xx_mean_nm_6_22, clos_xx_mean_nm_6_22 = wfe_6_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_6_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_26, clos_mean_nm_6_26, open_xx_mean_nm_6_26, clos_xx_mean_nm_6_26 = wfe_6_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_6_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6_30, clos_mean_nm_6_30, open_xx_mean_nm_6_30, clos_xx_mean_nm_6_30 = wfe_6_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 7 Sodium

# %%
os.chdir("30km60asR_15as7S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_7_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_0, clos_mean_nm_7_0, open_xx_mean_nm_7_0, clos_xx_mean_nm_7_0 = wfe_7_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_7_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_2, clos_mean_nm_7_2, open_xx_mean_nm_7_2, clos_xx_mean_nm_7_2 = wfe_7_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_7_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_4, clos_mean_nm_7_4, open_xx_mean_nm_7_4, clos_xx_mean_nm_7_4 = wfe_7_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_7_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_6, clos_mean_nm_7_6, open_xx_mean_nm_7_6, clos_xx_mean_nm_7_6 = wfe_7_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_7_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_8, clos_mean_nm_7_8, open_xx_mean_nm_7_8, clos_xx_mean_nm_7_8 = wfe_7_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_7_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_10, clos_mean_nm_7_10, open_xx_mean_nm_7_10, clos_xx_mean_nm_7_10 = wfe_7_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_7_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_14, clos_mean_nm_7_14, open_xx_mean_nm_7_14, clos_xx_mean_nm_7_14 = wfe_7_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_7_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_18, clos_mean_nm_7_18, open_xx_mean_nm_7_18, clos_xx_mean_nm_7_18 = wfe_7_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_7_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_22, clos_mean_nm_7_22, open_xx_mean_nm_7_22, clos_xx_mean_nm_7_22 = wfe_7_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_7_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_26, clos_mean_nm_7_26, open_xx_mean_nm_7_26, clos_xx_mean_nm_7_26 = wfe_7_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_7_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_7_30, clos_mean_nm_7_30, open_xx_mean_nm_7_30, clos_xx_mean_nm_7_30 = wfe_7_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 8 Sodium

# %%
os.chdir("30km60asR_15as8S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_8_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_0, clos_mean_nm_8_0, open_xx_mean_nm_8_0, clos_xx_mean_nm_8_0 = wfe_8_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_8_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_2, clos_mean_nm_8_2, open_xx_mean_nm_8_2, clos_xx_mean_nm_8_2 = wfe_8_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_8_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_4, clos_mean_nm_8_4, open_xx_mean_nm_8_4, clos_xx_mean_nm_8_4 = wfe_8_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_8_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_6, clos_mean_nm_8_6, open_xx_mean_nm_8_6, clos_xx_mean_nm_8_6 = wfe_8_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_8_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_8, clos_mean_nm_8_8, open_xx_mean_nm_8_8, clos_xx_mean_nm_8_8 = wfe_8_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_8_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_10, clos_mean_nm_8_10, open_xx_mean_nm_8_10, clos_xx_mean_nm_8_10 = wfe_8_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_8_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_14, clos_mean_nm_8_14, open_xx_mean_nm_8_14, clos_xx_mean_nm_8_14 = wfe_8_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_8_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_18, clos_mean_nm_8_18, open_xx_mean_nm_8_18, clos_xx_mean_nm_8_18 = wfe_8_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_8_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_22, clos_mean_nm_8_22, open_xx_mean_nm_8_22, clos_xx_mean_nm_8_22 = wfe_8_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_8_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_26, clos_mean_nm_8_26, open_xx_mean_nm_8_26, clos_xx_mean_nm_8_26 = wfe_8_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_8_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_8_30, clos_mean_nm_8_30, open_xx_mean_nm_8_30, clos_xx_mean_nm_8_30 = wfe_8_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 9 Sodium

# %%
os.chdir("30km60asR_15as9S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_9_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_0, clos_mean_nm_9_0, open_xx_mean_nm_9_0, clos_xx_mean_nm_9_0 = wfe_9_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_9_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_2, clos_mean_nm_9_2, open_xx_mean_nm_9_2, clos_xx_mean_nm_9_2 = wfe_9_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_9_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_4, clos_mean_nm_9_4, open_xx_mean_nm_9_4, clos_xx_mean_nm_9_4 = wfe_9_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_9_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_6, clos_mean_nm_9_6, open_xx_mean_nm_9_6, clos_xx_mean_nm_9_6 = wfe_9_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_9_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_8, clos_mean_nm_9_8, open_xx_mean_nm_9_8, clos_xx_mean_nm_9_8 = wfe_9_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_9_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_10, clos_mean_nm_9_10, open_xx_mean_nm_9_10, clos_xx_mean_nm_9_10 = wfe_9_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_9_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_14, clos_mean_nm_9_14, open_xx_mean_nm_9_14, clos_xx_mean_nm_9_14 = wfe_9_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_9_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_18, clos_mean_nm_9_18, open_xx_mean_nm_9_18, clos_xx_mean_nm_9_18 = wfe_9_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_9_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_22, clos_mean_nm_9_22, open_xx_mean_nm_9_22, clos_xx_mean_nm_9_22 = wfe_9_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_9_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_26, clos_mean_nm_9_26, open_xx_mean_nm_9_26, clos_xx_mean_nm_9_26 = wfe_9_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_9_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_9_30, clos_mean_nm_9_30, open_xx_mean_nm_9_30, clos_xx_mean_nm_9_30 = wfe_9_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 10 Sodium

# %%
os.chdir("30km60asR_15as10S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_10_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_0, clos_mean_nm_10_0, open_xx_mean_nm_10_0, clos_xx_mean_nm_10_0 = wfe_10_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_10_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_2, clos_mean_nm_10_2, open_xx_mean_nm_10_2, clos_xx_mean_nm_10_2 = wfe_10_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_10_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_4, clos_mean_nm_10_4, open_xx_mean_nm_10_4, clos_xx_mean_nm_10_4 = wfe_10_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_10_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_6, clos_mean_nm_10_6, open_xx_mean_nm_10_6, clos_xx_mean_nm_10_6 = wfe_10_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_10_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_8, clos_mean_nm_10_8, open_xx_mean_nm_10_8, clos_xx_mean_nm_10_8 = wfe_10_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_10_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_10, clos_mean_nm_10_10, open_xx_mean_nm_10_10, clos_xx_mean_nm_10_10 = wfe_10_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_10_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_14, clos_mean_nm_10_14, open_xx_mean_nm_10_14, clos_xx_mean_nm_10_14 = wfe_10_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_10_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_18, clos_mean_nm_10_18, open_xx_mean_nm_10_18, clos_xx_mean_nm_10_18 = wfe_10_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_10_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_22, clos_mean_nm_10_22, open_xx_mean_nm_10_22, clos_xx_mean_nm_10_22 = wfe_10_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_10_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_26, clos_mean_nm_10_26, open_xx_mean_nm_10_26, clos_xx_mean_nm_10_26 = wfe_10_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_10_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_10_30, clos_mean_nm_10_30, open_xx_mean_nm_10_30, clos_xx_mean_nm_10_30 = wfe_10_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 11 Sodium

# %%
os.chdir("30km60asR_15as11S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_11_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_0, clos_mean_nm_11_0, open_xx_mean_nm_11_0, clos_xx_mean_nm_11_0 = wfe_11_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_11_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_2, clos_mean_nm_11_2, open_xx_mean_nm_11_2, clos_xx_mean_nm_11_2 = wfe_11_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_11_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_4, clos_mean_nm_11_4, open_xx_mean_nm_11_4, clos_xx_mean_nm_11_4 = wfe_11_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_11_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_6, clos_mean_nm_11_6, open_xx_mean_nm_11_6, clos_xx_mean_nm_11_6 = wfe_11_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_11_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_8, clos_mean_nm_11_8, open_xx_mean_nm_11_8, clos_xx_mean_nm_11_8 = wfe_11_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_11_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_10, clos_mean_nm_11_10, open_xx_mean_nm_11_10, clos_xx_mean_nm_11_10 = wfe_11_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_11_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_14, clos_mean_nm_11_14, open_xx_mean_nm_11_14, clos_xx_mean_nm_11_14 = wfe_11_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_11_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_18, clos_mean_nm_11_18, open_xx_mean_nm_11_18, clos_xx_mean_nm_11_18 = wfe_11_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_11_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_22, clos_mean_nm_11_22, open_xx_mean_nm_11_22, clos_xx_mean_nm_11_22 = wfe_11_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_11_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_26, clos_mean_nm_11_26, open_xx_mean_nm_11_26, clos_xx_mean_nm_11_26 = wfe_11_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_11_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_11_30, clos_mean_nm_11_30, open_xx_mean_nm_11_30, clos_xx_mean_nm_11_30 = wfe_11_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 12 Sodium

# %%
#os.chdir("30km60asR_15as12S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_12_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_0, clos_mean_nm_12_0, open_xx_mean_nm_12_0, clos_xx_mean_nm_12_0 = wfe_12_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_12_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_2, clos_mean_nm_12_2, open_xx_mean_nm_12_2, clos_xx_mean_nm_12_2 = wfe_12_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_12_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_4, clos_mean_nm_12_4, open_xx_mean_nm_12_4, clos_xx_mean_nm_12_4 = wfe_12_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_12_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_6, clos_mean_nm_12_6, open_xx_mean_nm_12_6, clos_xx_mean_nm_12_6 = wfe_12_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_12_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_8, clos_mean_nm_12_8, open_xx_mean_nm_12_8, clos_xx_mean_nm_12_8 = wfe_12_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_12_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_10, clos_mean_nm_12_10, open_xx_mean_nm_12_10, clos_xx_mean_nm_12_10 = wfe_12_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_12_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_14, clos_mean_nm_12_14, open_xx_mean_nm_12_14, clos_xx_mean_nm_12_14 = wfe_12_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_12_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_18, clos_mean_nm_12_18, open_xx_mean_nm_12_18, clos_xx_mean_nm_12_18 = wfe_12_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_12_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_22, clos_mean_nm_12_22, open_xx_mean_nm_12_22, clos_xx_mean_nm_12_22 = wfe_12_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_12_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_26, clos_mean_nm_12_26, open_xx_mean_nm_12_26, clos_xx_mean_nm_12_26 = wfe_12_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_12_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12_30, clos_mean_nm_12_30, open_xx_mean_nm_12_30, clos_xx_mean_nm_12_30 = wfe_12_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## 13 Sodium

# %%
os.chdir("30km60asR_15as13S_lgs_study1A")

os.chdir("0rayleigh")
# WFE
wfe_13_0 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_0, clos_mean_nm_13_0, open_xx_mean_nm_13_0, clos_xx_mean_nm_13_0 = wfe_13_0
os.chdir("..")

os.chdir("2rayleigh")
# WFE
wfe_13_2 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_2, clos_mean_nm_13_2, open_xx_mean_nm_13_2, clos_xx_mean_nm_13_2 = wfe_13_2
os.chdir("..")

os.chdir("4rayleigh")
# WFE
wfe_13_4 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_4, clos_mean_nm_13_4, open_xx_mean_nm_13_4, clos_xx_mean_nm_13_4 = wfe_13_4
os.chdir("..")

os.chdir("6rayleigh")
# WFE
wfe_13_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_6, clos_mean_nm_13_6, open_xx_mean_nm_13_6, clos_xx_mean_nm_13_6 = wfe_13_6
os.chdir("..")

os.chdir("8rayleigh")
# WFE
wfe_13_8 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_8, clos_mean_nm_13_8, open_xx_mean_nm_13_8, clos_xx_mean_nm_13_8 = wfe_13_8
os.chdir("..")

os.chdir("10rayleigh")
# WFE
wfe_13_10 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_10, clos_mean_nm_13_10, open_xx_mean_nm_13_10, clos_xx_mean_nm_13_10 = wfe_13_10
os.chdir("..")

os.chdir("14rayleigh")
# WFE
wfe_13_14 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_14, clos_mean_nm_13_14, open_xx_mean_nm_13_14, clos_xx_mean_nm_13_14 = wfe_13_14
os.chdir("..")

os.chdir("18rayleigh")
# WFE
wfe_13_18 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_18, clos_mean_nm_13_18, open_xx_mean_nm_13_18, clos_xx_mean_nm_13_18 = wfe_13_18
os.chdir("..")

os.chdir("22rayleigh")
# WFE
wfe_13_22 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_22, clos_mean_nm_13_22, open_xx_mean_nm_13_22, clos_xx_mean_nm_13_22 = wfe_13_22
os.chdir("..")

os.chdir("26rayleigh")
# WFE
wfe_13_26 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_26, clos_mean_nm_13_26, open_xx_mean_nm_13_26, clos_xx_mean_nm_13_26 = wfe_13_26
os.chdir("..")

os.chdir("30rayleigh")
# WFE
wfe_13_30 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_13_30, clos_mean_nm_13_30, open_xx_mean_nm_13_30, clos_xx_mean_nm_13_30 = wfe_13_30
os.chdir("..")

os.chdir("..")

# %% [markdown]
# ## Plotting

# %%
zero_sodium = np.array([clos_xx_mean_nm_0_0[0][0], clos_xx_mean_nm_0_2[0][0], clos_xx_mean_nm_0_4[0][0], clos_xx_mean_nm_0_6[0][0], clos_xx_mean_nm_0_8[0][0], clos_xx_mean_nm_0_10[0][0], clos_xx_mean_nm_0_14[0][0], clos_xx_mean_nm_0_18[0][0], clos_xx_mean_nm_0_22[0][0], clos_xx_mean_nm_0_26[0][0], clos_xx_mean_nm_0_30[0][0]])
one_sodium = np.array([clos_xx_mean_nm_1_0[0][0], clos_xx_mean_nm_1_2[0][0], clos_xx_mean_nm_1_4[0][0], clos_xx_mean_nm_1_6[0][0], clos_xx_mean_nm_1_8[0][0], clos_xx_mean_nm_1_10[0][0], clos_xx_mean_nm_1_14[0][0], clos_xx_mean_nm_1_18[0][0], clos_xx_mean_nm_1_22[0][0], clos_xx_mean_nm_1_26[0][0], clos_xx_mean_nm_1_30[0][0]])
two_sodium = np.array([clos_xx_mean_nm_2_0[0][0], clos_xx_mean_nm_2_2[0][0], clos_xx_mean_nm_2_4[0][0], clos_xx_mean_nm_2_6[0][0], clos_xx_mean_nm_2_8[0][0], clos_xx_mean_nm_2_10[0][0], clos_xx_mean_nm_2_14[0][0], clos_xx_mean_nm_2_18[0][0], clos_xx_mean_nm_2_22[0][0], clos_xx_mean_nm_2_26[0][0], clos_xx_mean_nm_2_30[0][0]])
three_sodium = np.array([clos_xx_mean_nm_3_0[0][0], clos_xx_mean_nm_3_2[0][0], clos_xx_mean_nm_3_4[0][0], clos_xx_mean_nm_3_6[0][0], clos_xx_mean_nm_3_8[0][0], clos_xx_mean_nm_3_10[0][0], clos_xx_mean_nm_3_14[0][0], clos_xx_mean_nm_3_18[0][0], clos_xx_mean_nm_3_22[0][0], clos_xx_mean_nm_3_26[0][0], clos_xx_mean_nm_3_30[0][0]])
four_sodium = np.array([clos_xx_mean_nm_4_0[0][0], clos_xx_mean_nm_4_2[0][0], clos_xx_mean_nm_4_4[0][0], clos_xx_mean_nm_4_6[0][0], clos_xx_mean_nm_4_8[0][0], clos_xx_mean_nm_4_10[0][0], clos_xx_mean_nm_4_14[0][0], clos_xx_mean_nm_4_18[0][0], clos_xx_mean_nm_4_22[0][0], clos_xx_mean_nm_4_26[0][0], clos_xx_mean_nm_4_30[0][0]])
five_sodium = np.array([clos_xx_mean_nm_5_0[0][0], clos_xx_mean_nm_5_2[0][0], clos_xx_mean_nm_5_4[0][0], clos_xx_mean_nm_5_6[0][0], clos_xx_mean_nm_5_8[0][0], clos_xx_mean_nm_5_10[0][0], clos_xx_mean_nm_5_14[0][0], clos_xx_mean_nm_5_18[0][0], clos_xx_mean_nm_5_22[0][0], clos_xx_mean_nm_5_26[0][0], clos_xx_mean_nm_5_30[0][0]])
six_sodium = np.array([clos_xx_mean_nm_6_0[0][0], clos_xx_mean_nm_6_2[0][0], clos_xx_mean_nm_6_4[0][0], clos_xx_mean_nm_6_6[0][0], clos_xx_mean_nm_6_8[0][0], clos_xx_mean_nm_6_10[0][0], clos_xx_mean_nm_6_14[0][0], clos_xx_mean_nm_6_18[0][0], clos_xx_mean_nm_6_22[0][0], clos_xx_mean_nm_6_26[0][0], clos_xx_mean_nm_6_30[0][0]])
seven_sodium = np.array([clos_xx_mean_nm_7_0[0][0], clos_xx_mean_nm_7_2[0][0], clos_xx_mean_nm_7_4[0][0], clos_xx_mean_nm_7_6[0][0], clos_xx_mean_nm_7_8[0][0], clos_xx_mean_nm_7_10[0][0], clos_xx_mean_nm_7_14[0][0], clos_xx_mean_nm_7_18[0][0], clos_xx_mean_nm_7_22[0][0], clos_xx_mean_nm_7_26[0][0], clos_xx_mean_nm_7_30[0][0]])
eight_sodium = np.array([clos_xx_mean_nm_8_0[0][0], clos_xx_mean_nm_8_2[0][0], clos_xx_mean_nm_8_4[0][0], clos_xx_mean_nm_8_6[0][0], clos_xx_mean_nm_8_8[0][0], clos_xx_mean_nm_8_10[0][0], clos_xx_mean_nm_8_14[0][0], clos_xx_mean_nm_8_18[0][0], clos_xx_mean_nm_8_22[0][0], clos_xx_mean_nm_8_26[0][0], clos_xx_mean_nm_8_30[0][0]])
nine_sodium = np.array([clos_xx_mean_nm_9_0[0][0], clos_xx_mean_nm_9_2[0][0], clos_xx_mean_nm_9_4[0][0], clos_xx_mean_nm_9_6[0][0], clos_xx_mean_nm_9_8[0][0], clos_xx_mean_nm_9_10[0][0], clos_xx_mean_nm_9_14[0][0], clos_xx_mean_nm_9_18[0][0], clos_xx_mean_nm_9_22[0][0], clos_xx_mean_nm_9_26[0][0], clos_xx_mean_nm_9_30[0][0]])
ten_sodium = np.array([clos_xx_mean_nm_10_0[0][0], clos_xx_mean_nm_10_2[0][0], clos_xx_mean_nm_10_4[0][0], clos_xx_mean_nm_10_6[0][0], clos_xx_mean_nm_10_8[0][0], clos_xx_mean_nm_10_10[0][0], clos_xx_mean_nm_10_14[0][0], clos_xx_mean_nm_10_18[0][0], clos_xx_mean_nm_10_22[0][0], clos_xx_mean_nm_10_26[0][0], clos_xx_mean_nm_10_30[0][0]])
eleven_sodium = np.array([clos_xx_mean_nm_11_0[0][0], clos_xx_mean_nm_11_2[0][0], clos_xx_mean_nm_11_4[0][0], clos_xx_mean_nm_11_6[0][0], clos_xx_mean_nm_11_8[0][0], clos_xx_mean_nm_11_10[0][0], clos_xx_mean_nm_11_14[0][0], clos_xx_mean_nm_11_18[0][0], clos_xx_mean_nm_11_22[0][0], clos_xx_mean_nm_11_26[0][0], clos_xx_mean_nm_11_30[0][0]])
twelve_sodium = np.array([clos_xx_mean_nm_12_0[0][0], clos_xx_mean_nm_12_2[0][0], clos_xx_mean_nm_12_4[0][0], clos_xx_mean_nm_12_6[0][0], clos_xx_mean_nm_12_8[0][0], clos_xx_mean_nm_12_10[0][0], clos_xx_mean_nm_12_14[0][0], clos_xx_mean_nm_12_18[0][0], clos_xx_mean_nm_12_22[0][0], clos_xx_mean_nm_12_26[0][0], clos_xx_mean_nm_12_30[0][0]])
thirteen_sodium = np.array([clos_xx_mean_nm_13_0[0][0], clos_xx_mean_nm_13_2[0][0], clos_xx_mean_nm_13_4[0][0], clos_xx_mean_nm_13_6[0][0], clos_xx_mean_nm_13_8[0][0], clos_xx_mean_nm_13_10[0][0], clos_xx_mean_nm_13_14[0][0], clos_xx_mean_nm_13_18[0][0], clos_xx_mean_nm_13_22[0][0], clos_xx_mean_nm_13_26[0][0], clos_xx_mean_nm_13_30[0][0]])

# %%
#print(clos_xx_mean_nm_1_8[0][0])
#print(clos_xx_mean_nm_2_0[0][0])

# %%
rayleigh = [0, 2, 4, 6, 8, 10, 14, 18, 22, 26, 30]

plt.figure(figsize=(16,16))
plt.axvline(x = 0, color = 'grey', linestyle = '--')
plt.text(0.4, 945, '0 Rayleigh Beacons', fontsize=18, color = 'grey')
plt.plot(rayleigh, zero_sodium, color = "maroon", label = "0 Sodium LGS")
plt.plot(rayleigh, one_sodium, color = "red", label = "1 Sodium LGS")
plt.plot(rayleigh, two_sodium, color = "coral", label = "2 Sodium LGS")
plt.plot(rayleigh, three_sodium, color = "orange", label = "3 Sodium LGS")
plt.plot(rayleigh, four_sodium, color = "gold", label = "4 Sodium LGS")
plt.plot(rayleigh, five_sodium, color = "yellow", label = "5 Sodium LGS")
plt.plot(rayleigh, six_sodium, color = "green", label = "6 Sodium LGS")
plt.plot(rayleigh, seven_sodium, color = "seagreen", label = "7 Sodium LGS")
plt.plot(rayleigh, eight_sodium, color = "cyan", label = "8 Sodium LGS")
plt.plot(rayleigh, nine_sodium, color = "blue", label = "9 Sodium LGS")
plt.plot(rayleigh, ten_sodium, color = "darkblue", label = "10 Sodium LGS")
plt.plot(rayleigh, eleven_sodium, color = "indigo", label = "11 Sodium LGS")
plt.plot(rayleigh, twelve_sodium, color = "violet", label = "12 Sodium LGS")
plt.plot(rayleigh, thirteen_sodium, color = "hotpink", label = "13 Sodium LGS")
plt.title("Number of Rayleigh Beacons vs. Total WFE", fontsize=22)
plt.xlabel("Number of Rayleigh Beacons", fontsize=22)
plt.ylabel("Total WFE", fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=22, length=10, width=2)
plt.legend(bbox_to_anchor=(1.3, 1), loc='upper right', fontsize='18')
plt.show()

# %%
zero_sodium_tt     = np.array([clos_xx_mean_nm_0_0[0][1], clos_xx_mean_nm_0_2[0][1], clos_xx_mean_nm_0_4[0][1], clos_xx_mean_nm_0_6[0][1], clos_xx_mean_nm_0_8[0][1], clos_xx_mean_nm_0_10[0][1], clos_xx_mean_nm_0_14[0][1], clos_xx_mean_nm_0_18[0][1], clos_xx_mean_nm_0_22[0][1], clos_xx_mean_nm_0_26[0][1], clos_xx_mean_nm_0_30[0][1]])
one_sodium_tt      = np.array([clos_xx_mean_nm_1_0[0][1], clos_xx_mean_nm_1_2[0][1], clos_xx_mean_nm_1_4[0][1], clos_xx_mean_nm_1_6[0][1], clos_xx_mean_nm_1_8[0][1], clos_xx_mean_nm_1_10[0][1], clos_xx_mean_nm_1_14[0][1], clos_xx_mean_nm_1_18[0][1], clos_xx_mean_nm_1_22[0][1], clos_xx_mean_nm_1_26[0][1], clos_xx_mean_nm_1_30[0][1]])
two_sodium_tt      = np.array([clos_xx_mean_nm_2_0[0][1], clos_xx_mean_nm_2_2[0][1], clos_xx_mean_nm_2_4[0][1], clos_xx_mean_nm_2_6[0][1], clos_xx_mean_nm_2_8[0][1], clos_xx_mean_nm_2_10[0][1], clos_xx_mean_nm_2_14[0][1], clos_xx_mean_nm_2_18[0][1], clos_xx_mean_nm_2_22[0][1], clos_xx_mean_nm_2_26[0][1], clos_xx_mean_nm_2_30[0][1]])
three_sodium_tt    = np.array([clos_xx_mean_nm_3_0[0][1], clos_xx_mean_nm_3_2[0][1], clos_xx_mean_nm_3_4[0][1], clos_xx_mean_nm_3_6[0][1], clos_xx_mean_nm_3_8[0][1], clos_xx_mean_nm_3_10[0][1], clos_xx_mean_nm_3_14[0][1], clos_xx_mean_nm_3_18[0][1], clos_xx_mean_nm_3_22[0][1], clos_xx_mean_nm_3_26[0][1], clos_xx_mean_nm_3_30[0][1]])
four_sodium_tt     = np.array([clos_xx_mean_nm_4_0[0][1], clos_xx_mean_nm_4_2[0][1], clos_xx_mean_nm_4_4[0][1], clos_xx_mean_nm_4_6[0][1], clos_xx_mean_nm_4_8[0][1], clos_xx_mean_nm_4_10[0][1], clos_xx_mean_nm_4_14[0][1], clos_xx_mean_nm_4_18[0][1], clos_xx_mean_nm_4_22[0][1], clos_xx_mean_nm_4_26[0][1], clos_xx_mean_nm_4_30[0][1]])
five_sodium_tt     = np.array([clos_xx_mean_nm_5_0[0][1], clos_xx_mean_nm_5_2[0][1], clos_xx_mean_nm_5_4[0][1], clos_xx_mean_nm_5_6[0][1], clos_xx_mean_nm_5_8[0][1], clos_xx_mean_nm_5_10[0][1], clos_xx_mean_nm_5_14[0][1], clos_xx_mean_nm_5_18[0][1], clos_xx_mean_nm_5_22[0][1], clos_xx_mean_nm_5_26[0][1], clos_xx_mean_nm_5_30[0][1]])
six_sodium_tt      = np.array([clos_xx_mean_nm_6_0[0][1], clos_xx_mean_nm_6_2[0][1], clos_xx_mean_nm_6_4[0][1], clos_xx_mean_nm_6_6[0][1], clos_xx_mean_nm_6_8[0][1], clos_xx_mean_nm_6_10[0][1], clos_xx_mean_nm_6_14[0][1], clos_xx_mean_nm_6_18[0][1], clos_xx_mean_nm_6_22[0][1], clos_xx_mean_nm_6_26[0][1], clos_xx_mean_nm_6_30[0][1]])
seven_sodium_tt    = np.array([clos_xx_mean_nm_7_0[0][1], clos_xx_mean_nm_7_2[0][1], clos_xx_mean_nm_7_4[0][1], clos_xx_mean_nm_7_6[0][1], clos_xx_mean_nm_7_8[0][1], clos_xx_mean_nm_7_10[0][1], clos_xx_mean_nm_7_14[0][1], clos_xx_mean_nm_7_18[0][1], clos_xx_mean_nm_7_22[0][1], clos_xx_mean_nm_7_26[0][1], clos_xx_mean_nm_7_30[0][1]])
eight_sodium_tt    = np.array([clos_xx_mean_nm_8_0[0][1], clos_xx_mean_nm_8_2[0][1], clos_xx_mean_nm_8_4[0][1], clos_xx_mean_nm_8_6[0][1], clos_xx_mean_nm_8_8[0][1], clos_xx_mean_nm_8_10[0][1], clos_xx_mean_nm_8_14[0][1], clos_xx_mean_nm_8_18[0][1], clos_xx_mean_nm_8_22[0][1], clos_xx_mean_nm_8_26[0][1], clos_xx_mean_nm_8_30[0][1]])
nine_sodium_tt     = np.array([clos_xx_mean_nm_9_0[0][1], clos_xx_mean_nm_9_2[0][1], clos_xx_mean_nm_9_4[0][1], clos_xx_mean_nm_9_6[0][1], clos_xx_mean_nm_9_8[0][1], clos_xx_mean_nm_9_10[0][1], clos_xx_mean_nm_9_14[0][1], clos_xx_mean_nm_9_18[0][1], clos_xx_mean_nm_9_22[0][1], clos_xx_mean_nm_9_26[0][1], clos_xx_mean_nm_9_30[0][1]])
ten_sodium_tt      = np.array([clos_xx_mean_nm_10_0[0][1], clos_xx_mean_nm_10_2[0][1], clos_xx_mean_nm_10_4[0][1], clos_xx_mean_nm_10_6[0][1], clos_xx_mean_nm_10_8[0][1], clos_xx_mean_nm_10_10[0][1], clos_xx_mean_nm_10_14[0][1], clos_xx_mean_nm_10_18[0][1], clos_xx_mean_nm_10_22[0][1], clos_xx_mean_nm_10_26[0][1], clos_xx_mean_nm_10_30[0][1]])
eleven_sodium_tt   = np.array([clos_xx_mean_nm_11_0[0][1], clos_xx_mean_nm_11_2[0][1], clos_xx_mean_nm_11_4[0][1], clos_xx_mean_nm_11_6[0][1], clos_xx_mean_nm_11_8[0][1], clos_xx_mean_nm_11_10[0][1], clos_xx_mean_nm_11_14[0][1], clos_xx_mean_nm_11_18[0][1], clos_xx_mean_nm_11_22[0][1], clos_xx_mean_nm_11_26[0][1], clos_xx_mean_nm_11_30[0][1]])
twelve_sodium_tt   = np.array([clos_xx_mean_nm_12_0[0][1], clos_xx_mean_nm_12_2[0][1], clos_xx_mean_nm_12_4[0][1], clos_xx_mean_nm_12_6[0][1], clos_xx_mean_nm_12_8[0][1], clos_xx_mean_nm_12_10[0][1], clos_xx_mean_nm_12_14[0][1], clos_xx_mean_nm_12_18[0][1], clos_xx_mean_nm_12_22[0][1], clos_xx_mean_nm_12_26[0][1], clos_xx_mean_nm_12_30[0][1]])
thirteen_sodium_tt = np.array([clos_xx_mean_nm_13_0[0][1], clos_xx_mean_nm_13_2[0][1], clos_xx_mean_nm_13_4[0][1], clos_xx_mean_nm_13_6[0][1], clos_xx_mean_nm_13_8[0][1], clos_xx_mean_nm_13_10[0][1], clos_xx_mean_nm_13_14[0][1], clos_xx_mean_nm_13_18[0][1], clos_xx_mean_nm_13_22[0][1], clos_xx_mean_nm_13_26[0][1], clos_xx_mean_nm_13_30[0][1]])

# %%
plt.figure(figsize=(16,16))
plt.axvline(x = 0, color = 'grey', linestyle = '--')
plt.text(0.4, 60.5, '0 Rayleigh Beacons', fontsize=18, color = 'grey')
plt.plot(rayleigh, zero_sodium_tt, color = "maroon", label = "0 Sodium LGS")
plt.plot(rayleigh, one_sodium_tt, color = "red", label = "1 Sodium LGS")
plt.plot(rayleigh, two_sodium_tt, color = "coral", label = "2 Sodium LGS")
plt.plot(rayleigh, three_sodium_tt, color = "orange", label = "3 Sodium LGS")
plt.plot(rayleigh, four_sodium_tt, color = "gold", label = "4 Sodium LGS")
plt.plot(rayleigh, five_sodium_tt, color = "yellow", label = "5 Sodium LGS")
plt.plot(rayleigh, six_sodium_tt, color = "green", label = "6 Sodium LGS")
plt.plot(rayleigh, seven_sodium_tt, color = "seagreen", label = "7 Sodium LGS")
plt.plot(rayleigh, eight_sodium_tt, color = "cyan", label = "8 Sodium LGS")
plt.plot(rayleigh, nine_sodium_tt, color = "blue", label = "9 Sodium LGS")
plt.plot(rayleigh, ten_sodium_tt, color = "darkblue", label = "10 Sodium LGS")
plt.plot(rayleigh, eleven_sodium_tt, color = "indigo", label = "11 Sodium LGS")
plt.plot(rayleigh, twelve_sodium_tt, color = "violet", label = "12 Sodium LGS")
plt.plot(rayleigh, thirteen_sodium_tt, color = "hotpink", label = "13 Sodium LGS")
plt.title("Number of Rayleigh Beacons vs. Tip-Tilt WFE", fontsize=22)
plt.xlabel("Number of Rayleigh Beacons", fontsize=22)
plt.ylabel("Tip-Tilt WFE", fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=22, length=10, width=2)
plt.legend(bbox_to_anchor=(1.3, 1), loc='upper right', fontsize='18')
plt.show()

# %%
zero_sodium_ho = np.array([clos_xx_mean_nm_0_0[0][2], clos_xx_mean_nm_0_2[0][2], clos_xx_mean_nm_0_4[0][2], clos_xx_mean_nm_0_6[0][2], clos_xx_mean_nm_0_8[0][2], clos_xx_mean_nm_0_10[0][2], clos_xx_mean_nm_0_14[0][2], clos_xx_mean_nm_0_18[0][2], clos_xx_mean_nm_0_22[0][2], clos_xx_mean_nm_0_26[0][2], clos_xx_mean_nm_0_30[0][2]])
one_sodium_ho = np.array([clos_xx_mean_nm_1_0[0][2], clos_xx_mean_nm_1_2[0][2], clos_xx_mean_nm_1_4[0][2], clos_xx_mean_nm_1_6[0][2], clos_xx_mean_nm_1_8[0][2], clos_xx_mean_nm_1_10[0][2], clos_xx_mean_nm_1_14[0][2], clos_xx_mean_nm_1_18[0][2], clos_xx_mean_nm_1_22[0][2], clos_xx_mean_nm_1_26[0][2], clos_xx_mean_nm_1_30[0][2]])
two_sodium_ho = np.array([clos_xx_mean_nm_2_0[0][2], clos_xx_mean_nm_2_2[0][2], clos_xx_mean_nm_2_4[0][2], clos_xx_mean_nm_2_6[0][2], clos_xx_mean_nm_2_8[0][2], clos_xx_mean_nm_2_10[0][2], clos_xx_mean_nm_2_14[0][2], clos_xx_mean_nm_2_18[0][2], clos_xx_mean_nm_2_22[0][2], clos_xx_mean_nm_2_26[0][2], clos_xx_mean_nm_2_30[0][2]])
three_sodium_ho = np.array([clos_xx_mean_nm_3_0[0][2], clos_xx_mean_nm_3_2[0][2], clos_xx_mean_nm_3_4[0][2], clos_xx_mean_nm_3_6[0][2], clos_xx_mean_nm_3_8[0][2], clos_xx_mean_nm_3_10[0][2], clos_xx_mean_nm_3_14[0][2], clos_xx_mean_nm_3_18[0][2], clos_xx_mean_nm_3_22[0][2], clos_xx_mean_nm_3_26[0][2], clos_xx_mean_nm_3_30[0][2]])
four_sodium_ho = np.array([clos_xx_mean_nm_4_0[0][2], clos_xx_mean_nm_4_2[0][2], clos_xx_mean_nm_4_4[0][2], clos_xx_mean_nm_4_6[0][2], clos_xx_mean_nm_4_8[0][2], clos_xx_mean_nm_4_10[0][2], clos_xx_mean_nm_4_14[0][2], clos_xx_mean_nm_4_18[0][2], clos_xx_mean_nm_4_22[0][2], clos_xx_mean_nm_4_26[0][2], clos_xx_mean_nm_4_30[0][2]])
five_sodium_ho = np.array([clos_xx_mean_nm_5_0[0][2], clos_xx_mean_nm_5_2[0][2], clos_xx_mean_nm_5_4[0][2], clos_xx_mean_nm_5_6[0][2], clos_xx_mean_nm_5_8[0][2], clos_xx_mean_nm_5_10[0][2], clos_xx_mean_nm_5_14[0][2], clos_xx_mean_nm_5_18[0][2], clos_xx_mean_nm_5_22[0][2], clos_xx_mean_nm_5_26[0][2], clos_xx_mean_nm_5_30[0][2]])
six_sodium_ho = np.array([clos_xx_mean_nm_6_0[0][2], clos_xx_mean_nm_6_2[0][2], clos_xx_mean_nm_6_4[0][2], clos_xx_mean_nm_6_6[0][2], clos_xx_mean_nm_6_8[0][2], clos_xx_mean_nm_6_10[0][2], clos_xx_mean_nm_6_14[0][2], clos_xx_mean_nm_6_18[0][2], clos_xx_mean_nm_6_22[0][2], clos_xx_mean_nm_6_26[0][2], clos_xx_mean_nm_6_30[0][2]])
seven_sodium_ho = np.array([clos_xx_mean_nm_7_0[0][2], clos_xx_mean_nm_7_2[0][2], clos_xx_mean_nm_7_4[0][2], clos_xx_mean_nm_7_6[0][2], clos_xx_mean_nm_7_8[0][2], clos_xx_mean_nm_7_10[0][2], clos_xx_mean_nm_7_14[0][2], clos_xx_mean_nm_7_18[0][2], clos_xx_mean_nm_7_22[0][2], clos_xx_mean_nm_7_26[0][2], clos_xx_mean_nm_7_30[0][2]])
eight_sodium_ho = np.array([clos_xx_mean_nm_8_0[0][2], clos_xx_mean_nm_8_2[0][2], clos_xx_mean_nm_8_4[0][2], clos_xx_mean_nm_8_6[0][2], clos_xx_mean_nm_8_8[0][2], clos_xx_mean_nm_8_10[0][2], clos_xx_mean_nm_8_14[0][2], clos_xx_mean_nm_8_18[0][2], clos_xx_mean_nm_8_22[0][2], clos_xx_mean_nm_8_26[0][2], clos_xx_mean_nm_8_30[0][2]])
nine_sodium_ho = np.array([clos_xx_mean_nm_9_0[0][2], clos_xx_mean_nm_9_2[0][2], clos_xx_mean_nm_9_4[0][2], clos_xx_mean_nm_9_6[0][2], clos_xx_mean_nm_9_8[0][2], clos_xx_mean_nm_9_10[0][2], clos_xx_mean_nm_9_14[0][2], clos_xx_mean_nm_9_18[0][2], clos_xx_mean_nm_9_22[0][2], clos_xx_mean_nm_9_26[0][2], clos_xx_mean_nm_9_30[0][2]])
ten_sodium_ho = np.array([clos_xx_mean_nm_10_0[0][2], clos_xx_mean_nm_10_2[0][2], clos_xx_mean_nm_10_4[0][2], clos_xx_mean_nm_10_6[0][2], clos_xx_mean_nm_10_8[0][2], clos_xx_mean_nm_10_10[0][2], clos_xx_mean_nm_10_14[0][2], clos_xx_mean_nm_10_18[0][2], clos_xx_mean_nm_10_22[0][2], clos_xx_mean_nm_10_26[0][2], clos_xx_mean_nm_10_30[0][2]])
eleven_sodium_ho = np.array([clos_xx_mean_nm_11_0[0][2], clos_xx_mean_nm_11_2[0][2], clos_xx_mean_nm_11_4[0][2], clos_xx_mean_nm_11_6[0][2], clos_xx_mean_nm_11_8[0][2], clos_xx_mean_nm_11_10[0][2], clos_xx_mean_nm_11_14[0][2], clos_xx_mean_nm_11_18[0][2], clos_xx_mean_nm_11_22[0][2], clos_xx_mean_nm_11_26[0][2], clos_xx_mean_nm_11_30[0][2]])
twelve_sodium_ho = np.array([clos_xx_mean_nm_12_0[0][2], clos_xx_mean_nm_12_2[0][2], clos_xx_mean_nm_12_4[0][2], clos_xx_mean_nm_12_6[0][2], clos_xx_mean_nm_12_8[0][2], clos_xx_mean_nm_12_10[0][2], clos_xx_mean_nm_12_14[0][2], clos_xx_mean_nm_12_18[0][2], clos_xx_mean_nm_12_22[0][2], clos_xx_mean_nm_12_26[0][2], clos_xx_mean_nm_12_30[0][2]])
thirteen_sodium_ho = np.array([clos_xx_mean_nm_13_0[0][2], clos_xx_mean_nm_13_2[0][2], clos_xx_mean_nm_13_4[0][2], clos_xx_mean_nm_13_6[0][2], clos_xx_mean_nm_13_8[0][2], clos_xx_mean_nm_13_10[0][2], clos_xx_mean_nm_13_14[0][2], clos_xx_mean_nm_13_18[0][2], clos_xx_mean_nm_13_22[0][2], clos_xx_mean_nm_13_26[0][2], clos_xx_mean_nm_13_30[0][2]])

# %%
plt.figure(figsize=(16,16))
plt.axvline(x = 0, color = 'grey', linestyle = '--')
plt.text(0.4, 945, '0 Rayleigh Beacons', fontsize=18, color = 'grey')
plt.plot(rayleigh, zero_sodium_ho, color = "maroon", label = "0 Sodium LGS")
plt.plot(rayleigh, one_sodium_ho, color = "red", label = "1 Sodium LGS")
plt.plot(rayleigh, two_sodium_ho, color = "coral", label = "2 Sodium LGS")
plt.plot(rayleigh, three_sodium_ho, color = "orange", label = "3 Sodium LGS")
plt.plot(rayleigh, four_sodium_ho, color = "gold", label = "4 Sodium LGS")
plt.plot(rayleigh, five_sodium_ho, color = "yellow", label = "5 Sodium LGS")
plt.plot(rayleigh, six_sodium_ho, color = "green", label = "6 Sodium LGS")
plt.plot(rayleigh, seven_sodium_ho, color = "seagreen", label = "7 Sodium LGS")
plt.plot(rayleigh, eight_sodium_ho, color = "cyan", label = "8 Sodium LGS")
plt.plot(rayleigh, nine_sodium_ho, color = "blue", label = "9 Sodium LGS")
plt.plot(rayleigh, ten_sodium_ho, color = "darkblue", label = "10 Sodium LGS")
plt.plot(rayleigh, eleven_sodium_ho, color = "indigo", label = "11 Sodium LGS")
plt.plot(rayleigh, twelve_sodium_ho, color = "violet", label = "12 Sodium LGS")
plt.plot(rayleigh, thirteen_sodium_ho, color = "hotpink", label = "13 Sodium LGS")
plt.title("Number of Rayleigh Beacons vs. High-Order WFE", fontsize=22)
plt.xlabel("Number of Rayleigh Beacons", fontsize=22)
plt.ylabel("High-Order WFE", fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=22, length=10, width=2)
plt.legend(bbox_to_anchor=(1.3, 1), loc='upper right', fontsize='18')
plt.show()

# %%
print(clos_xx_mean_nm_1_30[0][0])
print(clos_xx_mean_nm_2_2[0][0])
# Out:
# 248.0559136268673
# 239.07689903483424

# %%
print(clos_xx_mean_nm_1_2[0][0])
# Out:
# 302.989570779363
