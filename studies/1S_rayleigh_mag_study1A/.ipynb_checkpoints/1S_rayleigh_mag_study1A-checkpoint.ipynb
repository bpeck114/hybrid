# %% [markdown]
# # Rayleigh: 20km On-Axis MCAO Rayleigh Watt Study

# %%
import os, fnmatch
import importlib
import pylab as plt
import numpy as np
from astropy.io import fits


# Specific packages (may need extra steps to import)
import readbin
from paarti.utils import maos_utils
from paarti import psfs, psf_plots
from paarti import psfs, psf_plots
from paarti.psf_metrics import metrics
from bpeck.hybrid import on_axis_study
from bpeck.mcao import act_study

# %% [markdown]
# ## Parameters

# %%
seed = 1
bandpass = 3

# %% [markdown]
# # Preparation

# %%
os.getcwd()
# Out:
# '/System/Volumes/Data/mnt/g2/scratch/bpeck/mcao/hybrid/1S_rayleigh_mag_study1A'

# %%
os.chdir("..")

# %%
os.getcwd()
# Out:
# '/System/Volumes/Data/mnt/g2/scratch/bpeck/mcao/hybrid'

# %% [markdown]
# ## 6 Watts

# %%
os.chdir("1S_rayleigh_mag_study1A")

os.chdir("6W")
# WFE
wfe_6 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_6, clos_mean_nm_6, open_xx_mean_nm_6, clos_xx_mean_nm_6 = wfe_6
os.chdir("..")

os.chdir("12W")
# WFE
wfe_12 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_12, clos_mean_nm_12, open_xx_mean_nm_12, clos_xx_mean_nm_12 = wfe_12
os.chdir("..")

os.chdir("25W")
# WFE
wfe_25 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_25, clos_mean_nm_25, open_xx_mean_nm_25, clos_xx_mean_nm_25 = wfe_25
os.chdir("..")

os.chdir("50W")
# WFE
wfe_50 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_50, clos_mean_nm_50, open_xx_mean_nm_50, clos_xx_mean_nm_50 = wfe_50
os.chdir("..")

os.chdir("100W")
# WFE
wfe_100 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_100, clos_mean_nm_100, open_xx_mean_nm_100, clos_xx_mean_nm_100 = wfe_100
os.chdir("..")

os.chdir("200W")
# WFE
wfe_200 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_200, clos_mean_nm_200, open_xx_mean_nm_200, clos_xx_mean_nm_200 = wfe_200
os.chdir("..")

os.chdir("400W")
# WFE
wfe_400 = act_study.get_wfe_metrics(seed=seed)
open_mean_nm_400, clos_mean_nm_400, open_xx_mean_nm_400, clos_xx_mean_nm_400 = wfe_400
os.chdir("..")

# %%
onerayleigh_total = np.array([clos_xx_mean_nm_6[0][0], clos_xx_mean_nm_12[0][0], clos_xx_mean_nm_25[0][0], clos_xx_mean_nm_50[0][0], clos_xx_mean_nm_100[0][0], clos_xx_mean_nm_200[0][0], clos_xx_mean_nm_400[0][0]]) 
onerayleigh_tt = np.array([clos_xx_mean_nm_6[0][1], clos_xx_mean_nm_12[0][1], clos_xx_mean_nm_25[0][1], clos_xx_mean_nm_50[0][1], clos_xx_mean_nm_100[0][1], clos_xx_mean_nm_200[0][1], clos_xx_mean_nm_400[0][1]]) 
onerayleigh_ho = np.array([clos_xx_mean_nm_6[0][2], clos_xx_mean_nm_12[0][2], clos_xx_mean_nm_25[0][2], clos_xx_mean_nm_50[0][2], clos_xx_mean_nm_100[0][2], clos_xx_mean_nm_200[0][2], clos_xx_mean_nm_400[0][2]])

# %%
watts = [6, 12, 25, 50, 100, 200, 400]

plt.figure(figsize=(16,16))
plt.plot(watts, onerayleigh_total, color = "blue", label = "Total WFE")
plt.plot(watts, onerayleigh_tt, color = "green", label = "Tip-Tilt WFE")
plt.plot(watts, onerayleigh_ho, color = "red", label = "High-Order WFE")
plt.title("Rayleigh Beacon Power (Watts) vs. Wavefront Error", fontsize=22)
plt.xlabel("Wavefront Error", fontsize=22)
plt.ylabel("Total WFE", fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=22, length=10, width=2)
plt.legend(bbox_to_anchor=(1.4, 1), loc='upper right', fontsize='18')
plt.show()

# %%
print(clos_xx_mean_nm_6[0][0])
print(clos_xx_mean_nm_12[0][0])
print(clos_xx_mean_nm_25[0][0])
print(clos_xx_mean_nm_50[0][0])
print(clos_xx_mean_nm_100[0][0]) 
print(clos_xx_mean_nm_200[0][0]) 
print(clos_xx_mean_nm_400[0][0])
# Out:
# 458.86897141498525
# 458.86897141498525
# 458.86897141498525
# 458.86897141498525
# 458.86897141498525
# 458.86897141498525
# 458.86897141498525
