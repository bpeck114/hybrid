# %% [markdown]
# # Hybrid: 4 Rayleigh 1 Sodium On-Axis Study
# `4R1S_on_axis_study1A.ipynb`
# : The goal of this jupyter notebook is to produce plots of point-spread function (PSF) metrics and RMS wave-front error (WFE) for the on-axis hybrid LGS trade study. The current plots include:
# * Height vs. Strehl
# * Height vs. FWHM
# * Height vs. EE80
# * Height vs. WFE
# * Height vs. WFE (1000 step burn-in)

# %% [markdown]
# ## Setup

# %%
import os
import importlib
import pylab as plt
import numpy as np


# Specific packages (may need extra steps to import)
from paarti.utils import maos_utils
from paarti import psfs, psf_plots
from paarti.psf_metrics import metrics
from bpeck.hybrid import on_axis_study

# %% [markdown]
# ## Parameters

# %%
height = [20, 22, 24, 26, 28, 30] # kilometers
seed = 1
bandpass = 3
start_index = 1000

# %matplotlib inline

# %% [markdown]
# ## Directory Structure
# For this notebook, directories must be structured as the following:
# ```
# on_axis_study/
# |--- 4R1S_on_axis_study1A.ipynb
# |--- 20km/
# |--- 22km/
# |--- 24km/
# |--- 26km/
# |--- 28km/
# |--- 30km/
# ```
# Where `4R1S_on_axis_study1A/` is just a name for the study, this can be changed and it won't affect the note book, `on_axis_rayleigh_study1A.ipynb` is the name of this notebook. After this notebook has been run, the directory system will look like:
# ```
# 4R1S_on_axis_study1A/
# |--- 4R1S_on_axis_study1A.ipynb
# |--- 20km/
# |--- 22km/
# |--- 24km/
# |--- 26km/
# |--- 28km/
# |--- 30km/
# |--- on_axis_study_plots/
# ```
# Where `on_axis_study_plots/` is the location where this notebook will drop all PSF and WFE plots.

# %%
# Location of plots created 
output_folder = 'on_axis_study_plots/'
os.makedirs(output_folder, exist_ok=True)

# %% [markdown]
# ### 20km

# %%
os.chdir("20km")

# %%
# PSF Metrics
mets_20 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_20, strehl_20, fwhm_g_20, fwhm_emp_20, r_ee80_20 = mets_20

# WFE
wfe_20 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_20, clos_mean_nm_20 = wfe_20

wfe_burn_20 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_20, burn_clos_mean_nm_20 = wfe_burn_20

# %%
os.chdir ("..")

# %% [markdown]
# ### 22km

# %%
os.chdir("22km")

# %%
# PSF Metrics
mets_22 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_22, strehl_22, fwhm_g_22, fwhm_emp_22, r_ee80_22 = mets_22 

# WFE
wfe_22 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_22, clos_mean_nm_22 = wfe_22

wfe_burn_22 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_22, burn_clos_mean_nm_22 = wfe_burn_22

# %%
os.chdir ("..")

# %% [markdown]
# ### 24km

# %%
os.chdir("24km")

# %%
# PSF Metrics
mets_24 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_24, strehl_24, fwhm_g_24, fwhm_emp_24, r_ee80_24 = mets_24 

# WFE
wfe_24 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_24, clos_mean_nm_24 = wfe_24

wfe_burn_24 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_24, burn_clos_mean_nm_24 = wfe_burn_24

# %%
os.chdir ("..")

# %% [markdown]
# ### 26km

# %%
os.chdir ("26km")

# %%
# PSF Metrics
mets_26 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_26, strehl_26, fwhm_g_26, fwhm_emp_26, r_ee80_26 = mets_26 

# WFE
wfe_26 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_26, clos_mean_nm_26 = wfe_26

wfe_burn_26 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_26, burn_clos_mean_nm_26 = wfe_burn_26

# %%
os.chdir ("..")

# %% [markdown]
# ### 28km

# %%
os.chdir ("28km")

# %%
# PSF Metrics
mets_28 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_28, strehl_28, fwhm_g_28, fwhm_emp_28, r_ee80_28 = mets_28 

# WFE
wfe_28 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_28, clos_mean_nm_28 = wfe_28

wfe_burn_28 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_28, burn_clos_mean_nm_28 = wfe_burn_28

# %%
os.chdir ("..")

# %% [markdown]
# ### 30km

# %%
os.chdir ("30km")

# %%
# PSF Metrics
mets_30 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_30, strehl_30, fwhm_g_30, fwhm_emp_30, r_ee80_30 = mets_30

# WFE
wfe_30 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_30, clos_mean_nm_30 = wfe_30

wfe_burn_30 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_30, burn_clos_mean_nm_30 = wfe_burn_30

# %%
os.chdir ("..")

# %% [markdown]
# ## Results

# %% [markdown]
# ### Height vs. Strehl

# %%
strehl_800 = np.array([strehl_20[0], strehl_22[0], strehl_24[0], strehl_26[0], strehl_28[0], strehl_30[0]])
strehl_1000 = np.array([strehl_20[1], strehl_22[1], strehl_24[1], strehl_26[1], strehl_28[1], strehl_30[1]])
strehl_1250 = np.array([strehl_20[2], strehl_22[2], strehl_24[2], strehl_26[2], strehl_28[2], strehl_30[2]])
strehl_1650 = np.array([strehl_20[3], strehl_22[3], strehl_24[3], strehl_26[3], strehl_28[3], strehl_30[3]])
strehl_2120 = np.array([strehl_20[4], strehl_22[4], strehl_24[4], strehl_26[4], strehl_28[4], strehl_30[4]])

plt.figure(figsize=(4,4))
plt.plot(height, strehl_2120, color = "red", label = "2120 nm")
plt.plot(height, strehl_1650, color = "orange", label = "1000 nm")
plt.plot(height, strehl_1250, color = "green", label = "1250 nm")
plt.plot(height, strehl_1000, color = "cyan", label = "1650 nm")
plt.plot(height, strehl_800, color = "blue", label = "800 nm")
plt.title("Height of Rayleigh Beacon (km) vs. Strehl Ratio")
plt.xlabel("Height of Rayleigh Beacon (km)")
plt.ylabel("Strehl Ratio")
plt.legend(bbox_to_anchor=(1.45, 1), loc='upper right')
plt.show()

# %% [markdown]
# ### Height vs. FWHM (gaussian)

# %%
fwhm_g_800 = np.array([fwhm_g_20[0], fwhm_g_22[0], fwhm_g_24[0], fwhm_g_26[0], fwhm_g_28[0], fwhm_g_30[0]])
fwhm_g_1000 = np.array([fwhm_g_20[1], fwhm_g_22[1], fwhm_g_24[1], fwhm_g_26[1], fwhm_g_28[1], fwhm_g_30[1]])
fwhm_g_1250 = np.array([fwhm_g_20[2], fwhm_g_22[2], fwhm_g_24[2], fwhm_g_26[2], fwhm_g_28[2],  fwhm_g_30[2]])
fwhm_g_1650 = np.array([fwhm_g_20[3], fwhm_g_22[3], fwhm_g_24[3], fwhm_g_26[3], fwhm_g_28[3],  fwhm_g_30[3]])
fwhm_g_2120 = np.array([fwhm_g_20[4], fwhm_g_22[4], fwhm_g_24[4], fwhm_g_26[4], fwhm_g_28[4], fwhm_g_30[4]])

plt.figure(figsize=(4,4))
plt.plot(height, fwhm_g_2120, color = "red", label = "2120 nm")
plt.plot(height, fwhm_g_1650, color = "orange", label = "1000 nm")
plt.plot(height, fwhm_g_1250, color = "green", label = "1250 nm")
plt.plot(height, fwhm_g_1000, color = "cyan", label = "1650 nm")
plt.plot(height, fwhm_g_800, color = "blue", label = "800 nm")
plt.title("Height of Rayleigh Beacon (km) vs. FWHM (Gaussian)")
plt.xlabel("Height of Rayleigh Beacon (km)")
plt.ylabel("FWHM (Gaussian)")
plt.legend(bbox_to_anchor=(1.45, 1), loc='upper right')
plt.show()

# %% [markdown]
# ### Height vs. FWHM (empircal)

# %%
fwhm_emp_800 = np.array([fwhm_emp_20[0], fwhm_emp_22[0], fwhm_emp_24[0], fwhm_emp_26[0], fwhm_emp_28[0], fwhm_emp_30[0]])
fwhm_emp_1000 = np.array([fwhm_emp_20[1], fwhm_emp_22[1], fwhm_emp_24[1], fwhm_emp_26[1], fwhm_emp_28[1], fwhm_emp_30[1]])
fwhm_emp_1250 = np.array([fwhm_emp_20[2], fwhm_emp_22[2], fwhm_emp_24[2], fwhm_emp_26[2], fwhm_emp_28[2], fwhm_emp_30[2]])
fwhm_emp_1650 = np.array([fwhm_emp_20[3], fwhm_emp_22[3], fwhm_emp_24[3], fwhm_emp_26[3], fwhm_emp_28[3], fwhm_emp_30[3]])
fwhm_emp_2120 = np.array([fwhm_emp_20[4], fwhm_emp_22[4], fwhm_emp_24[4], fwhm_emp_26[4], fwhm_emp_28[4], fwhm_emp_30[4]])

plt.figure(figsize=(4,4))
plt.plot(height, fwhm_emp_2120, color = "red", label = "2120 nm")
plt.plot(height, fwhm_emp_1650, color = "orange", label = "1000 nm")
plt.plot(height, fwhm_emp_1250, color = "green", label = "1250 nm")
plt.plot(height, fwhm_emp_1000, color = "cyan", label = "1650 nm")
plt.plot(height, fwhm_emp_800, color = "blue", label = "800 nm")
plt.title("Height of Rayleigh Beacon (km) vs. FWHM (Empirical)")
plt.xlabel("Height of Rayleigh Beacon (km)")
plt.ylabel("FWHM (Empirical)")
plt.legend(bbox_to_anchor=(1.45, 1), loc='upper right')
plt.show()

# %% [markdown]
# ### Height vs. EE80

# %%
r_ee80_800 = np.array([r_ee80_20[0], r_ee80_22[0], r_ee80_24[0], r_ee80_26[0], r_ee80_28[0], r_ee80_30[0]])
r_ee80_1000 = np.array([r_ee80_20[1], r_ee80_22[1], r_ee80_24[1], r_ee80_26[1], r_ee80_28[1], r_ee80_30[1]])
r_ee80_1250 = np.array([r_ee80_20[2], r_ee80_22[2], r_ee80_24[2], r_ee80_26[2], r_ee80_28[2], r_ee80_30[2]])
r_ee80_1650 = np.array([r_ee80_20[3], r_ee80_22[3], r_ee80_24[3], r_ee80_26[3], r_ee80_28[3], r_ee80_30[3]])
r_ee80_2120 = np.array([r_ee80_20[4], r_ee80_22[4], r_ee80_24[4], r_ee80_26[4], r_ee80_28[4], r_ee80_30[4]])

plt.figure(figsize=(4,4))
plt.plot(height, r_ee80_2120, color = "red", label = "2120 nm")
plt.plot(height, r_ee80_1650, color = "orange", label = "1000 nm")
plt.plot(height, r_ee80_1250, color = "green", label = "1250 nm")
plt.plot(height, r_ee80_1000, color = "cyan", label = "1650 nm")
plt.plot(height, r_ee80_800, color = "blue", label = "800 nm")
plt.title("Height of Rayleigh Beacon (km) vs. 80% Encircled Energy")
plt.xlabel("Height of Rayleigh Beacon (km)")
plt.ylabel("80% Encircled Energy")
plt.legend(bbox_to_anchor=(1.45, 1), loc='upper right')
plt.show()

# %% [markdown]
# ### Height vs. WFE

# %%
total_wfe = np.array([clos_mean_nm_20[0], clos_mean_nm_22[0], clos_mean_nm_24[0], clos_mean_nm_26[0], clos_mean_nm_28[0], clos_mean_nm_30[0]])
tt_wfe = np.array([clos_mean_nm_20[1], clos_mean_nm_22[1], clos_mean_nm_24[1], clos_mean_nm_26[1], clos_mean_nm_28[1], clos_mean_nm_30[1]])
ho_wfe = np.array([clos_mean_nm_20[2], clos_mean_nm_22[2], clos_mean_nm_24[2], clos_mean_nm_26[2], clos_mean_nm_28[2], clos_mean_nm_30[2]])


plt.figure(figsize=(4,4))
plt.plot(height, total_wfe, color = "blue", label = "Total RMS WFE")
plt.plot(height, ho_wfe, color = "red", label = "High-Order RMS WFE")
plt.plot(height, tt_wfe, color = "green", label = "Tip-Tilt RMS WFE")
plt.title("Height of Rayleigh Beacon (km) vs. WFE")
plt.xlabel("Height of Rayleigh Beacon (km)")
plt.ylabel("WFE")
plt.legend(bbox_to_anchor=(1.75, 1), loc='upper right')
plt.show()

# %% [markdown]
# ### Height vs. WFE (1000 step burn-in)

# %%
total_burn_wfe = np.array([burn_clos_mean_nm_20[0], burn_clos_mean_nm_22[0], burn_clos_mean_nm_24[0], burn_clos_mean_nm_26[0], burn_clos_mean_nm_28[0], burn_clos_mean_nm_30[0]])
tt_burn_wfe = np.array([burn_clos_mean_nm_20[1], burn_clos_mean_nm_22[1], burn_clos_mean_nm_24[1], burn_clos_mean_nm_26[1], burn_clos_mean_nm_28[1], burn_clos_mean_nm_30[1]])
ho_burn_wfe = np.array([burn_clos_mean_nm_20[2], burn_clos_mean_nm_22[2], burn_clos_mean_nm_24[2], burn_clos_mean_nm_26[2], burn_clos_mean_nm_28[2], burn_clos_mean_nm_30[2]])


plt.figure(figsize=(4,4))
plt.plot(height, total_burn_wfe, color = "blue", label = "Total RMS WFE")
plt.plot(height, ho_burn_wfe, color = "red", label = "High-Order RMS WFE")
plt.plot(height, tt_burn_wfe, color = "green", label = "Tip-Tilt RMS WFE")
plt.title("Height of Rayleigh Beacon (km) vs. WFE (1000 step burn-in)")
plt.xlabel("Height of Rayleigh Beacon (km)")
plt.ylabel("WFE")
plt.legend(bbox_to_anchor=(1.75, 1), loc='upper right')
plt.show()

# %% [markdown]
# # Hybrid & Rayleigh Comparison
# The goal of this section of the notebook is to compare a singular Rayleigh beacon with a single Rayleigh beacon and sodium laser guide star. For this we will be importing data from a different directory than the current study.

# %% [markdown]
# # Import Other Data

# %%
hybrid_directory = "../studies/on_axis_study3B"
os.chdir(hybrid_directory)

# %% [markdown]
# ### 20km (Hybrid)

# %%
os.chdir("20km")

# %%
# PSF Metrics
mets_1R_20 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_1R_20, strehl_1R_20, fwhm_g_1R_20, fwhm_emp_1R_20, r_ee80_1R_20 = mets_1R_20

# WFE
wfe_1R_20 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_1R_20, clos_mean_nm_1R_20 = wfe_1R_20

wfe_burn_1R_20 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_1R_20, burn_clos_mean_nm_1R_20 = wfe_burn_1R_20

# %%
os.chdir ("..")

# %% [markdown]
# ### 22km (Hybrid)

# %%
os.chdir("22km")

# %%
# PSF Metrics
mets_1R_22 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_1R_22, strehl_1R_22, fwhm_g_1R_22, fwhm_emp_1R_22, r_ee80_1R_22 = mets_1R_22 

# WFE
wfe_1R_22 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_1R_22, clos_mean_nm_1R_22 = wfe_1R_22

wfe_burn_1R_22 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_1R_22, burn_clos_mean_nm_1R_22 = wfe_burn_1R_22

# %%
os.chdir ("..")

# %% [markdown]
# ### 24km (Hybrid)

# %%
os.chdir("24km")

# %%
# PSF Metrics
mets_1R_24 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_1R_24, strehl_1R_24, fwhm_g_1R_24, fwhm_emp_1R_24, r_ee80_1R_24 = mets_1R_24 

# WFE
wfe_1R_24 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_1R_24, clos_mean_nm_1R_24 = wfe_1R_24

wfe_burn_1R_24 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_1R_24, burn_clos_mean_nm_1R_24 = wfe_burn_1R_24

# %%
os.chdir ("..")

# %% [markdown]
# ### 26km (Hybrid)

# %%
os.chdir("26km")

# %%
# PSF Metrics
mets_1R_26 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_1R_26, strehl_1R_26, fwhm_g_1R_26, fwhm_emp_1R_26, r_ee80_1R_26 = mets_1R_26 

# WFE
wfe_1R_26 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_1R_26, clos_mean_nm_1R_26 = wfe_1R_26

wfe_burn_1R_26 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_1R_26, burn_clos_mean_nm_1R_26 = wfe_burn_1R_26

# %%
os.chdir ("..")

# %% [markdown]
# ### 28km (Hybrid)

# %%
os.chdir("28km")

# %%
# PSF Metrics
mets_1R_28 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_1R_28, strehl_1R_28, fwhm_g_1R_28, fwhm_emp_1R_28, r_ee80_1R_28 = mets_1R_28 

# WFE
wfe_1R_28 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_1R_28, clos_mean_nm_1R_28 = wfe_1R_28

wfe_burn_1R_28 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_1R_28, burn_clos_mean_nm_1R_28 = wfe_burn_1R_28

# %%
os.chdir ("..")

# %% [markdown]
# ### 30km (Hybrid)

# %%
os.chdir("30km")

# %%
# PSF Metrics
mets_1R_30 = on_axis_study.get_psf_metrics_x0y0(seed=seed)
wvl_1R_30, strehl_1R_30, fwhm_g_1R_30, fwhm_emp_1R_30, r_ee80_1R_30 = mets_1R_30

# WFE
wfe_1R_30 = on_axis_study.get_wfe_metrics(seed=seed)
open_mean_nm_1R_30, clos_mean_nm_1R_30 = wfe_1R_30

wfe_burn_1R_30 = on_axis_study.get_burn_wfe_metrics(start_index=start_index)
burn_open_mean_nm_1R_30, burn_clos_mean_nm_1R_30 = wfe_burn_1R_30

# %%
os.chdir ("..")

# %% [markdown]
# ## Results of Comparison

# %% [markdown]
# ### Height vs. WFE (Comparison)

# %%
total_1R_wfe = np.array([clos_mean_nm_1R_20[0], clos_mean_nm_1R_22[0], clos_mean_nm_1R_24[0], clos_mean_nm_1R_26[0], clos_mean_nm_1R_28[0], clos_mean_nm_1R_30[0]])
tt_1R_wfe = np.array([clos_mean_nm_1R_20[1], clos_mean_nm_1R_22[1], clos_mean_nm_1R_24[1], clos_mean_nm_1R_26[1], clos_mean_nm_1R_28[1], clos_mean_nm_1R_30[1]])
ho_1R_wfe = np.array([clos_mean_nm_1R_20[2], clos_mean_nm_1R_22[2], clos_mean_nm_1R_24[2], clos_mean_nm_1R_26[2], clos_mean_nm_1R_28[2], clos_mean_nm_1R_30[2]])



plt.figure(figsize=(4,4))
plt.plot(height, total_wfe, color = "blue", label = "Total RMS WFE (4 Rayleigh)")
plt.plot(height, ho_wfe, color = "red", label = "High-Order RMS WFE (4 Rayleigh)")
plt.plot(height, tt_wfe, color = "green", label = "Tip-Tilt RMS WFE (4 Rayleigh)")
plt.plot(height, total_1R_wfe, color = "blue", label = "Total RMS WFE (1 Rayleigh)", linestyle='--')
plt.plot(height, ho_1R_wfe, color = "red", label = "High-Order RMS WFE (1 Rayleigh)", linestyle='--')
plt.plot(height, tt_1R_wfe, color = "green", label = "Tip-Tilt RMS WFE (1 Rayleigh)", linestyle='--')
plt.title("Height of Rayleigh Beacon (km) vs. WFE")
plt.xlabel("Height of Rayleigh Beacon (km)")
plt.ylabel("WFE")
plt.legend(bbox_to_anchor=(2, 1), loc='upper right')
plt.show()

# %% [markdown]
# ### Height vs. WFE (1000 step burn-in) (Comparison)

# %%
total_burn_1R_wfe = np.array([burn_clos_mean_nm_1R_20[0], burn_clos_mean_nm_1R_22[0], burn_clos_mean_nm_1R_24[0], burn_clos_mean_nm_1R_26[0], burn_clos_mean_nm_1R_28[0], burn_clos_mean_nm_1R_30[0]])
tt_burn_1R_wfe = np.array([burn_clos_mean_nm_1R_20[1], burn_clos_mean_nm_1R_22[1], burn_clos_mean_nm_1R_24[1], burn_clos_mean_nm_1R_26[1], burn_clos_mean_nm_1R_28[1], burn_clos_mean_nm_1R_30[1]])
ho_burn_1R_wfe = np.array([burn_clos_mean_nm_1R_20[2], burn_clos_mean_nm_1R_22[2], burn_clos_mean_nm_1R_24[2], burn_clos_mean_nm_1R_26[2], burn_clos_mean_nm_1R_28[2], burn_clos_mean_nm_1R_30[2]])



plt.figure(figsize=(4,4))
plt.plot(height, total_burn_wfe, color = "blue", label = "Total RMS WFE (4 Rayleigh)")
plt.plot(height, ho_burn_wfe, color = "red", label = "High-Order RMS WFE (4 Rayleigh)")
plt.plot(height, tt_burn_wfe, color = "green", label = "Tip-Tilt RMS WFE (4 Rayleigh)")
plt.plot(height, total_burn_1R_wfe, color = "blue", label = "Total RMS WFE (1 Rayleigh)", linestyle='--')
plt.plot(height, ho_burn_1R_wfe, color = "red", label = "High-Order RMS WFE (1 Rayleigh)", linestyle='--')
plt.plot(height, tt_burn_1R_wfe, color = "green", label = "Tip-Tilt RMS WFE (1 Rayleigh)", linestyle='--')
plt.title("Height of Rayleigh Beacon (km) vs. WFE (1000 step burn-in)")
plt.xlabel("Height of Rayleigh Beacon (km)")
plt.ylabel("WFE")
plt.legend(bbox_to_anchor=(2, 1), loc='upper right')
plt.show()
